# %%
import warnings
import awkward as ak
import hist as hs
from hist.intervals import ratio_uncertainty
import numpy as np
import pandas as pd

import mplhep as hep
import matplotlib.pyplot as plt

import pickle

plt.style.use(hep.style.CMS)
#plt.style.use('dark_background')

# %%
prefixes = ['ID_control','ID_optimized']
fileset = [
    'PhiToPi0Pi0_mPhi0p3_ctau300',
    'PhiToPi0Pi0_mPhi1p0_ctau300',
    'PhiToPiPlusPiMinus_mPhi0p3_ctau300',
    'PhiToPiPlusPiMinus_mPhi1p0_ctau300',
    'data',
    ]
out = {}
for prefix in prefixes:
    out[prefix] = {}
    for dataset in fileset:
        filename = f'{prefix}/{dataset}_{prefix}.pickle'
        infile = open(filename, 'rb')
        out[prefix][dataset] = pickle.load(infile)
        infile.close()

# %%
{dataset: {key: out[cat][dataset][key] for key in out[cat][dataset]} for dataset in
# Out:
# ID_control PhiToPi0Pi0_mPhi0p3_ctau300
# numEvents_pretrigger, 1846676
# numEvents_|muonId| == 13, 1846536
# numEvents_muonHLTReq, 260091
# numEvents_|muonEta| < 1.5, 254748
# numEvents_muonPt > 7, 252852
# numEvents_soft_muon_ID, 248596
# numEvents_leadMuon_cut, 248596
# numEvents_posttrigger, 248596
# numEvents_llp_acc, 96034
# numEvents_num Cluster > 0, 11854
# numEvents_dR_gllp_cls < .4, 8725
# numEvents_dR_lmuon_cls > .8, 8339
# numEvents_ME1112_veto, 4753
# numEvents_re12_veto, 4693
# numEvents_mb1_veto, 4664
# numEvents_rb1_veto, 4616
# numEvents_muon_veto_pt < 20, 4592
# numEvents_-5 < cls_time < 12.5, 4577
# numEvents_|cls_timeSpread| < 20, 4445
# numEvents_|cls_eta| < 1.9, 2613
# numEvents_cut_based_ID, 2021
# ID_control PhiToPi0Pi0_mPhi1p0_ctau300
# numEvents_pretrigger, 1114939
# numEvents_|muonId| == 13, 1114864
# numEvents_muonHLTReq, 168498
# numEvents_|muonEta| < 1.5, 164192
# numEvents_muonPt > 7, 163013
# numEvents_soft_muon_ID, 160265
# numEvents_leadMuon_cut, 160265
# numEvents_posttrigger, 160265
# numEvents_llp_acc, 58078
# numEvents_num Cluster > 0, 9460
# numEvents_dR_gllp_cls < .4, 7625
# numEvents_dR_lmuon_cls > .8, 7260
# numEvents_ME1112_veto, 3974
# numEvents_re12_veto, 3940
# numEvents_mb1_veto, 3914
# numEvents_rb1_veto, 3880
# numEvents_muon_veto_pt < 20, 3853
# numEvents_-5 < cls_time < 12.5, 3833
# numEvents_|cls_timeSpread| < 20, 3748
# numEvents_|cls_eta| < 1.9, 1916
# numEvents_cut_based_ID, 1445
# ID_control PhiToPiPlusPiMinus_mPhi0p3_ctau300
# numEvents_pretrigger, 1551411
# numEvents_|muonId| == 13, 1551319
# numEvents_muonHLTReq, 219683
# numEvents_|muonEta| < 1.5, 214992
# numEvents_muonPt > 7, 213451
# numEvents_soft_muon_ID, 209911
# numEvents_leadMuon_cut, 209911
# numEvents_posttrigger, 209911
# numEvents_llp_acc, 81481
# numEvents_num Cluster > 0, 12753
# numEvents_dR_gllp_cls < .4, 10210
# numEvents_dR_lmuon_cls > .8, 9735
# numEvents_ME1112_veto, 5919
# numEvents_re12_veto, 5850
# numEvents_mb1_veto, 5740
# numEvents_rb1_veto, 5693
# numEvents_muon_veto_pt < 20, 5518
# numEvents_-5 < cls_time < 12.5, 5500
# numEvents_|cls_timeSpread| < 20, 5283
# numEvents_|cls_eta| < 1.9, 3106
# numEvents_cut_based_ID, 2564
# ID_control PhiToPiPlusPiMinus_mPhi1p0_ctau300
# numEvents_pretrigger, 1125810
# numEvents_|muonId| == 13, 1125736
# numEvents_muonHLTReq, 170609
# numEvents_|muonEta| < 1.5, 166206
# numEvents_muonPt > 7, 164980
# numEvents_soft_muon_ID, 162139
# numEvents_leadMuon_cut, 162139
# numEvents_posttrigger, 162139
# numEvents_llp_acc, 58454
# numEvents_num Cluster > 0, 13953
# numEvents_dR_gllp_cls < .4, 12280
# numEvents_dR_lmuon_cls > .8, 11672
# numEvents_ME1112_veto, 6479
# numEvents_re12_veto, 6401
# numEvents_mb1_veto, 6247
# numEvents_rb1_veto, 6176
# numEvents_muon_veto_pt < 20, 6025
# numEvents_-5 < cls_time < 12.5, 6009
# numEvents_|cls_timeSpread| < 20, 5799
# numEvents_|cls_eta| < 1.9, 3127
# numEvents_cut_based_ID, 2547
# ID_control data
# numEvents_pretrigger, 25667521
# numEvents_|muonId| == 13, 25667155
# numEvents_muonHLTReq, 24764401
# numEvents_|muonEta| < 1.5, 22954060
# numEvents_muonPt > 7, 22896397
# numEvents_soft_muon_ID, 22039911
# numEvents_leadMuon_cut, 22039911
# numEvents_posttrigger, 22039911
# numEvents_llp_acc, 22039911
# numEvents_num Cluster > 0, 5032009
# numEvents_dR_gllp_cls < .4, 5032009
# numEvents_dR_lmuon_cls > .8, 3638409
# numEvents_ME1112_veto, 225311
# numEvents_re12_veto, 223242
# numEvents_mb1_veto, 221292
# numEvents_rb1_veto, 220292
# numEvents_muon_veto_pt < 20, 219480
# numEvents_-5 < cls_time < 12.5, 37360
# numEvents_|cls_timeSpread| < 20, 25562
# numEvents_|cls_eta| < 1.9, 4713
# numEvents_cut_based_ID, 2504
# ID_optimized PhiToPi0Pi0_mPhi0p3_ctau300
# numEvents_pretrigger, 1846676
# numEvents_|muonId| == 13, 1846536
# numEvents_muonHLTReq, 260091
# numEvents_|muonEta| < 1.5, 254748
# numEvents_muonPt > 7, 252852
# numEvents_soft_muon_ID, 248596
# numEvents_leadMuon_cut, 248596
# numEvents_posttrigger, 248596
# numEvents_llp_acc, 96034
# numEvents_num Cluster > 0, 11854
# numEvents_dR_gllp_cls < .4, 8725
# numEvents_dR_lmuon_cls > .8, 8339
# numEvents_ME1112_veto, 4753
# numEvents_re12_veto, 4693
# numEvents_mb1_veto, 4664
# numEvents_rb1_veto, 4616
# numEvents_muon_veto_pt < 20, 4592
# numEvents_-5 < cls_time < 12.5, 4577
# numEvents_|cls_timeSpread| < 20, 4445
# numEvents_|cls_eta| < 1.9, 2613
# numEvents_cut_based_ID, 1898
# ID_optimized PhiToPi0Pi0_mPhi1p0_ctau300
# numEvents_pretrigger, 1114939
# numEvents_|muonId| == 13, 1114864
# numEvents_muonHLTReq, 168498
# numEvents_|muonEta| < 1.5, 164192
# numEvents_muonPt > 7, 163013
# numEvents_soft_muon_ID, 160265
# numEvents_leadMuon_cut, 160265
# numEvents_posttrigger, 160265
# numEvents_llp_acc, 58078
# numEvents_num Cluster > 0, 9460
# numEvents_dR_gllp_cls < .4, 7625
# numEvents_dR_lmuon_cls > .8, 7260
# numEvents_ME1112_veto, 3974
# numEvents_re12_veto, 3940
# numEvents_mb1_veto, 3914
# numEvents_rb1_veto, 3880
# numEvents_muon_veto_pt < 20, 3853
# numEvents_-5 < cls_time < 12.5, 3833
# numEvents_|cls_timeSpread| < 20, 3748
# numEvents_|cls_eta| < 1.9, 1916
# numEvents_cut_based_ID, 1422
# ID_optimized PhiToPiPlusPiMinus_mPhi0p3_ctau300
# numEvents_pretrigger, 1551411
# numEvents_|muonId| == 13, 1551319
# numEvents_muonHLTReq, 219683
# numEvents_|muonEta| < 1.5, 214992
# numEvents_muonPt > 7, 213451
# numEvents_soft_muon_ID, 209911
# numEvents_leadMuon_cut, 209911
# numEvents_posttrigger, 209911
# numEvents_llp_acc, 81481
# numEvents_num Cluster > 0, 12753
# numEvents_dR_gllp_cls < .4, 10210
# numEvents_dR_lmuon_cls > .8, 9735
# numEvents_ME1112_veto, 5919
# numEvents_re12_veto, 5850
# numEvents_mb1_veto, 5740
# numEvents_rb1_veto, 5693
# numEvents_muon_veto_pt < 20, 5518
# numEvents_-5 < cls_time < 12.5, 5500
# numEvents_|cls_timeSpread| < 20, 5283
# numEvents_|cls_eta| < 1.9, 3106
# numEvents_cut_based_ID, 2511
# ID_optimized PhiToPiPlusPiMinus_mPhi1p0_ctau300
# numEvents_pretrigger, 1125810
# numEvents_|muonId| == 13, 1125736
# numEvents_muonHLTReq, 170609
# numEvents_|muonEta| < 1.5, 166206
# numEvents_muonPt > 7, 164980
# numEvents_soft_muon_ID, 162139
# numEvents_leadMuon_cut, 162139
# numEvents_posttrigger, 162139
# numEvents_llp_acc, 58454
# numEvents_num Cluster > 0, 13953
# numEvents_dR_gllp_cls < .4, 12280
# numEvents_dR_lmuon_cls > .8, 11672
# numEvents_ME1112_veto, 6479
# numEvents_re12_veto, 6401
# numEvents_mb1_veto, 6247
# numEvents_rb1_veto, 6176
# numEvents_muon_veto_pt < 20, 6025
# numEvents_-5 < cls_time < 12.5, 6009
# numEvents_|cls_timeSpread| < 20, 5799
# numEvents_|cls_eta| < 1.9, 3127
# numEvents_cut_based_ID, 2509
# ID_optimized data
# numEvents_pretrigger, 25667521
# numEvents_|muonId| == 13, 25667155
# numEvents_muonHLTReq, 24764401
# numEvents_|muonEta| < 1.5, 22954060
# numEvents_muonPt > 7, 22896397
# numEvents_soft_muon_ID, 22039911
# numEvents_leadMuon_cut, 22039911
# numEvents_posttrigger, 22039911
# numEvents_llp_acc, 22039911
# numEvents_num Cluster > 0, 5032009
# numEvents_dR_gllp_cls < .4, 5032009
# numEvents_dR_lmuon_cls > .8, 3638409
# numEvents_ME1112_veto, 225311
# numEvents_re12_veto, 223242
# numEvents_mb1_veto, 221292
# numEvents_rb1_veto, 220292
# numEvents_muon_veto_pt < 20, 219480
# numEvents_-5 < cls_time < 12.5, 37360
# numEvents_|cls_timeSpread| < 20, 25562
# numEvents_|cls_eta| < 1.9, 4713
# numEvents_cut_based_ID, 2662
